# %% [markdown]
# #Tensorboard

# %%
import pandas as pd
import numpy as np
from google.colab import drive

drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
df = pd.read_csv('/drive/My Drive/Colab Notebooks/Deep Learning Course (Jose Portilia)/4. Basic Artificial Neural Networks - ANNs/cancer_classification.csv')

# %% [markdown]
# ##Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('benign_0__mal_1', axis = 1).values
y = df['benign_0__mal_1'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 101)

# %% [markdown]
# ##Scaling Data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ##Creating a Model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation

# %%
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard

# %%
early_stop = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, patience = 25)

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# ##Creating a Tensorboard Callbacks

# %%
from datetime import datetime

# %%
datetime.now().strftime("%Y-%M-%d--%H%M")
# Out:
# '2021-05-10--1205'

# %%
log_directory = "/drive/My Drive/Colab Notebooks/Deep Learning Course (Jose Portilia)/4. Basic Artificial Neural Networks - ANNs/logs/fit"

board = TensorBoard(log_dir = log_directory,
                    histogram_freq = 1,
                    write_graph = True,
                    write_images = True,
                    update_freq = 'epoch',
                    profile_batch = 2,
                    embeddings_freq = 1)

# %% [markdown]
# **Create model layers**

# %%
model = Sequential()

model.add(Dense(units = 30, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(units = 15, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(units = 1, activation = 'sigmoid'))

model.compile(loss = 'binary_crossentropy', optimizer = 'adam')

# %% [markdown]
# ##Train the Model

# %%
model.fit(x = X_train,
          y = y_train,
          epochs = 600,
          validation_data = (X_test, y_test),
          verbose = 1,
          callbacks = [early_stop, board]
          )
# Out:
# Epoch 1/600
# 14/14 [==============================] - 1s 27ms/step - loss: 0.6895 - val_loss: 0.6797
# Epoch 2/600
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6767 - val_loss: 0.6507
# Epoch 3/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6573 - val_loss: 0.6190
# Epoch 4/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6396 - val_loss: 0.5853
# Epoch 5/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6219 - val_loss: 0.5541
# Epoch 6/600
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6051 - val_loss: 0.5308
# Epoch 7/600
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5485 - val_loss: 0.5007
# Epoch 8/600
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5623 - val_loss: 0.4741
# Epoch 9/600
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5251 - val_loss: 0.4467
# Epoch 10/600
# ...

# %% [markdown]
# ##Running Tensorboard

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %%
log_directory
# Out:
# '/drive/My Drive/Colab Notebooks/Deep Learning Course (Jose Portilia)/4. Basic Artificial Neural Networks - ANNs/logs/fit'

# %%
# %tensorboard --logdir='/drive/My Drive/Colab Notebooks/Deep Learning Course (Jose Portilia)/4. Basic Artificial Neural Networks - ANNs/logs/fit'
# Out:
# Reusing TensorBoard on port 6006 (pid 1431), started 0:07:03 ago. (Use '!kill 1431' to kill it.)
